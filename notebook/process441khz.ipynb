# %%
import json
import os
import math
import librosa

DATASET_PATH = "dataset_irm"
JSON_PATH = "data441_1.json"
SAMPLE_RATE = 44100
TRACK_DURATION = 3 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=1)
# Out:
# t_irm\voi\226__[voi][nod][cou_fol]2440__3.wav, segment:1
# dataset_irm\voi\227__[voi][nod][pop_roc]2311__1.wav, segment:1
# dataset_irm\voi\227__[voi][nod][pop_roc]2311__2.wav, segment:1
# dataset_irm\voi\227__[voi][nod][pop_roc]2311__3.wav, segment:1
# dataset_irm\voi\228__[voi][dru][pop_roc]2466__1.wav, segment:1
# dataset_irm\voi\228__[voi][dru][pop_roc]2466__2.wav, segment:1
# dataset_irm\voi\228__[voi][dru][pop_roc]2466__3.wav, segment:1
# dataset_irm\voi\230__[voi][dru][cou_fol]2369__1.wav, segment:1
# dataset_irm\voi\230__[voi][dru][cou_fol]2369__2.wav, segment:1
# dataset_irm\voi\230__[voi][dru][cou_fol]2369__3.wav, segment:1
# dataset_irm\voi\231__[voi][nod][cou_fol]2388__1.wav, segment:1
# dataset_irm\voi\231__[voi][nod][cou_fol]2388__2.wav, segment:1
# dataset_irm\voi\231__[voi][nod][cou_fol]2388__3.wav, segment:1
# dataset_irm\voi\233__[voi][dru][pop_roc]2472__1.wav, segment:1
# dataset_irm\voi\233__[voi][dru][pop_roc]2472__2.wav, segment:1
# dataset_irm\voi\233__[voi][dru][pop_roc]2472__3.wav, segment:1
# dataset_irm\voi\234__[voi][dru][cou_fol]2415__1.wav, segment:1
# dataset_irm\voi\234__[voi][dru][cou_fol]2415__2.wav, segment:1
# dataset_irm\voi\234__[voi][dru][cou_fol]2415__3.wav, segment:1
# dataset_irm\voi\235__[voi][dru][pop_roc]2328__1.wav, segment:1
# dataset_irm\voi\235__[voi][dru][pop_roc]2328__2.wav, segment:1
# dataset_irm\voi\235__[voi][dru][pop_roc]2328__3.wav, segment:1
# dataset_irm\voi\236__[voi][nod][cou_fol]2450__1.wav, segment:1
# dataset_irm\voi\236__[voi][nod][cou_fol]2450__2.wav, segment:1
# dataset_irm\voi\236__[voi][nod][cou_fol]2450__3.wav, segment:1
# dataset_irm\voi\237__[voi][dru][cou_fol]2366__1.wav, segment:1
# dataset_irm\voi\237__[voi][dru][cou_fol]2366__2.wav, segment:1
# dataset_irm\voi\237__[voi][dru][cou_fol]2366__3.wav, segment:1
# dataset_irm\voi\238__[voi][nod][cou_fol]2418__1.wav, segment:1
# dataset_irm\voi\238__[voi][nod][cou_fol]2418__2.wav, segment:1
# dataset_irm\voi\238__[voi][nod][cou_fol]2418__3.wav, segment:1
# dataset_irm\voi\239__[voi][nod][pop_roc]2478__1.wav, segment:1
# dataset_irm\voi\239__[voi][nod][pop_roc]2478__2.wav, segment:1
# dataset_irm\voi\239__[voi][nod][pop_roc]2478__3.wav, segment:1
# dataset_irm\voi\240__[voi][dru][cou_fol]2392__1.wav, segment:1
# dataset_irm\voi\240__[voi][dru][cou_fol]2392__2.wav, segment:1
# dataset_irm\voi\240__[voi][dru][cou_fol]2392__3.wav, segment:1
# dataset_irm\voi\241__[voi][nod][cou_fol]2421__1.wav, segment:1
# dataset_irm\voi\241__[voi][nod][cou_fol]2421__2.wav, segment:1
# dataset_irm\voi\241__[voi][nod][cou_fol]2421__3.wav, segment:1
# dataset_irm\voi\242__[voi][dru][pop_roc]2324__1.wav, segment:1
# dataset_irm\voi\242__[voi][dru][pop_roc]2324__2.wav, segment:1
# dataset_irm\voi\242__[voi][dru][pop_roc]2324__3.wav, segment:1
# dataset_irm\voi\243__[voi][dru][pop_roc]2325__1.wav, segment:1
# dataset_irm\voi\243__[voi][dru][pop_roc]2325__2.wav, segment:1
# dataset_irm\voi\243__[voi][dru][pop_roc]2325__3.wav, segment:1
# dataset_irm\voi\244__[voi][nod][cou_fol]2441__1.wav, segment:1
# dataset_irm\voi\244__[voi][nod][cou_fol]2441__2.wav, segment:1
# dataset_irm\voi\244__[voi][nod][cou_fol]2441__3.wav, segment:1
# dataset_irm\voi\247__[voi][---][cou_fol]2376__1.wav, segment:1
# dataset_irm\voi\247__[voi][---][cou_fol]2376__2.wav, segment:1
# dataset_irm\voi\247__[voi][---][cou_fol]2376__3.wav, segment:1
# dataset_irm\voi\248__[voi][nod][cou_fol]2385__1.wav, segment:1
# dataset_irm\voi\248__[voi][nod][cou_fol]2385__2.wav, segment:1
# dataset_irm\voi\248__[voi][nod][cou_fol]2385__3.wav, segment:1
# dataset_irm\voi\251__[voi][dru][pop_roc]2308__1.wav, segment:1
# dataset_irm\voi\251__[voi][dru][pop_roc]2308__2.wav, segment:1
# dataset_irm\voi\251__[voi][dru][pop_roc]2308__3.wav, segment:1
# dataset_irm\voi\253__[voi][nod][pop_roc]2330__1.wav, segment:1
# dataset_irm\voi\253__[voi][nod][pop_roc]2330__2.wav, segment:1
# dataset_irm\voi\253__[voi][nod][pop_roc]2330__3.wav, segment:1
# dataset_irm\voi\254__[voi][nod][cou_fol]2444__1.wav, segment:1
# dataset_irm\voi\254__[voi][nod][cou_fol]2444__2.wav, segment:1
# dataset_irm\voi\254__[voi][nod][cou_fol]2444__3.wav, segment:1
# dataset_irm\voi\256__[voi][nod][cou_fol]2387__1.wav, segment:1
# dataset_irm\voi\256__[voi][nod][cou_fol]2387__2.wav, segment:1
# dataset_irm\voi\256__[voi][nod][cou_fol]2387__3.wav, segment:1
# dataset_irm\voi\258__[voi][dru][lat_sou]2452__1.wav, segment:1
# dataset_irm\voi\258__[voi][dru][lat_sou]2452__2.wav, segment:1
# dataset_irm\voi\258__[voi][dru][lat_sou]2452__3.wav, segment:1
# dataset_irm\voi\261__[voi][dru][cou_fol]2408__1.wav, segment:1
